# %% [markdown]
# # Desafio 5
#
# Neste desafio, vamos praticar sobre redução de dimensionalidade com PCA e seleção de variáveis com RFE. Utilizaremos o _data set_ [Fifa 2019](https://www.kaggle.com/karangadiya/fifa19), contendo originalmente 89 variáveis de mais de 18 mil jogadores do _game_ FIFA 2019.
#
# > Obs.: Por favor, não modifique o nome das funções de resposta.

# %% [markdown]
# ## _Setup_ geral

# %%
from math import sqrt

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sct
import seaborn as sns
import statsmodels.api as sm
import statsmodels.stats as st
from sklearn.decomposition import PCA

from loguru import logger

# %%
# Algumas configurações para o matplotlib.
#%matplotlib inline

#from IPython.core.pylabtools import figsize


#figsize(12, 8)

#sns.set()

# %%
from sklearn.decomposition import PCA
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
pca = PCA(0.95)
regressor = LinearRegression()
rfe = RFE(regressor)

# %%
fifa = pd.read_csv("fifa.csv")

# %%
columns_to_drop = ["Unnamed: 0", "ID", "Name", "Photo", "Nationality", "Flag",
                   "Club", "Club Logo", "Value", "Wage", "Special", "Preferred Foot",
                   "International Reputation", "Weak Foot", "Skill Moves", "Work Rate",
                   "Body Type", "Real Face", "Position", "Jersey Number", "Joined",
                   "Loaned From", "Contract Valid Until", "Height", "Weight", "LS",
                   "ST", "RS", "LW", "LF", "CF", "RF", "RW", "LAM", "CAM", "RAM", "LM",
                   "LCM", "CM", "RCM", "RM", "LWB", "LDM", "CDM", "RDM", "RWB", "LB", "LCB",
                   "CB", "RCB", "RB", "Release Clause"
]

try:
    fifa.drop(columns_to_drop, axis=1, inplace=True)
except KeyError:
    logger.warning(f"Columns already dropped")

# %% [markdown]
# ## Inicia sua análise a partir daqui

# %%
fifa.describe()
# Out:
#                 Age       Overall     Potential      Crossing     Finishing  \
# count  18207.000000  18207.000000  18207.000000  18159.000000  18159.000000
# mean      25.122206     66.238699     71.307299     49.734181     45.550911
# std        4.669943      6.908930      6.136496     18.364524     19.525820
# min       16.000000     46.000000     48.000000      5.000000      2.000000
# 25%       21.000000     62.000000     67.000000     38.000000     30.000000
# 50%       25.000000     66.000000     71.000000     54.000000     49.000000
# 75%       28.000000     71.000000     75.000000     64.000000     62.000000
# max       45.000000     94.000000     95.000000     93.000000     95.000000
#
#        HeadingAccuracy  ShortPassing       Volleys     Dribbling  \
# count     18159.000000  18159.000000  18159.000000  18159.000000
# mean         52.298144     58.686712     42.909026     55.371001
# std          17.379909     14.699495     17.694408     18.910371
# ...

# %%
# Sua análise começa aqui.
fifa_aux = pd.DataFrame({
    'columns': fifa.columns,
    'types': fifa.dtypes,
    'size': fifa.shape[0],
    'missing': fifa.isna().sum(),
    'uniques': fifa.nunique()
})
fifa_aux['percentual'] = round(fifa_aux['missing'] / fifa_aux['size'], 2)
fifa_aux
# Out:
#                          columns    types   size  missing  uniques  percentual
# Age                          Age    int64  18207        0       29         0.0
# Overall                  Overall    int64  18207        0       48         0.0
# Potential              Potential    int64  18207        0       47         0.0
# Crossing                Crossing  float64  18207       48       89         0.0
# Finishing              Finishing  float64  18207       48       93         0.0
# HeadingAccuracy  HeadingAccuracy  float64  18207       48       91         0.0
# ShortPassing        ShortPassing  float64  18207       48       85         0.0
# Volleys                  Volleys  float64  18207       48       87         0.0
# Dribbling              Dribbling  float64  18207       48       94         0.0
# Curve                      Curve  float64  18207       48       89         0.0
# FKAccuracy            FKAccuracy  float64  18207       48       90         0.0
# ...

# %%
fifa_aux.percentual.plot.hist(bins=5)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
fifa_aux[fifa_aux.percentual == 0]['types'].value_counts()
# Out:
# float64    34
# int64       3
# Name: types, dtype: int64

# %%
fifa.dropna(inplace=True)

# %%
# Analise univariavel
for column in fifa_aux['columns']:
    print(column)
    fifa[column].plot.hist(bins = 50, log= True)
    plt.show()
# Out:
# Age
# Overall
# Potential
# Crossing
# Finishing
# HeadingAccuracy
# ShortPassing
# Volleys
# Dribbling
# Curve
# FKAccuracy
# LongPassing
# BallControl
# Acceleration
# SprintSpeed
# Agility
# Reactions
# Balance
# ShotPower
# Jumping
# Stamina
# Strength
# LongShots
# Aggression
# Interceptions
# Positioning
# Vision
# Penalties
# Composure
# Marking
# StandingTackle
# SlidingTackle
# GKDiving
# GKHandling
# GKKicking
# GKPositioning
# GKReflexes

# %%
#Analisando a correlacao entre as variaveis númericas
plt.figure(figsize = (30,30))
sns.heatmap(fifa[fifa_aux['columns']].corr().round(2), annot = True)

# %%
pca.fit(fifa)
# Out:
# PCA(n_components=0.95)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.56528056, 0.18102522, 0.05952834, 0.04342693, 0.02635323,
#        0.01207077, 0.01035505, 0.00852951, 0.00787863, 0.00720417,
#        0.0071818 , 0.00632894, 0.00519242, 0.00490798, 0.00474209])

# %% [markdown]
# ## Questão 1
#
# Qual fração da variância consegue ser explicada pelo primeiro componente principal de `fifa`? Responda como um único float (entre 0 e 1) arredondado para três casas decimais.

# %%
def q1():
    # Retorne aqui o resultado da questão 1.
    return float(round(pca.explained_variance_ratio_[0], 3))
# Out:
# 0.565

# %% [markdown]
# ## Questão 2
#
# Quantos componentes principais precisamos para explicar 95% da variância total? Responda como un único escalar inteiro.

# %%
def q2():
    # Retorne aqui o resultado da questão 2.
    return int(len(pca.explained_variance_ratio_))
# Out:
# 15

# %% [markdown]
# ## Questão 3
#
# Qual são as coordenadas (primeiro e segundo componentes principais) do ponto `x` abaixo? O vetor abaixo já está centralizado. Cuidado para __não__ centralizar o vetor novamente (por exemplo, invocando `PCA.transform()` nele). Responda como uma tupla de float arredondados para três casas decimais.

# %%
x = [0.87747123,  -1.24990363,  -1.3191255, -36.7341814,
     -35.55091139, -37.29814417, -28.68671182, -30.90902583,
     -42.37100061, -32.17082438, -28.86315326, -22.71193348,
     -38.36945867, -20.61407566, -22.72696734, -25.50360703,
     2.16339005, -27.96657305, -33.46004736,  -5.08943224,
     -30.21994603,   3.68803348, -36.10997302, -30.86899058,
     -22.69827634, -37.95847789, -22.40090313, -30.54859849,
     -26.64827358, -19.28162344, -34.69783578, -34.6614351,
     48.38377664,  47.60840355,  45.76793876,  44.61110193,
     49.28911284
]

# %%
def q3():
    # Retorne aqui o resultado da questão 3.
    components = pca.components_.dot(x)
    return (round(components[0], 3), round(components[1], 3))
# Out:
# (186.556, -6.592)

# %% [markdown]
# ## Questão 4
#
# Realiza RFE com estimador de regressão linear para selecionar cinco variáveis, eliminando uma a uma. Quais são as variáveis selecionadas? Responda como uma lista de nomes de variáveis.

# %%
def q4():
    # Retorne aqui o resultado da questão 4.
    rfe = RFE(estimator=regressor, n_features_to_select=5)
    X = fifa.drop(columns ='Overall')
    y = fifa['Overall']
    rfe.fit(X, y)
    return list(X.columns[rfe.support_])
# Out:
# ['Age', 'Potential', 'BallControl', 'Reactions', 'GKReflexes']
